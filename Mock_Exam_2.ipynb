# %% [markdown]
# **Requirements:**
#
# - Before you turn this problem in, make sure everything runs as expected.
# - Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
# - Fill in your name and student id below (inside of the quotation marks):

# %%
NAME = ""
STUDENT_ID = ""

# %% [markdown]
# ---

# %% [markdown]
# # **Inventory Planning under Uncertainty**
# (23 points in total)

# %% [markdown]
# # Case Background
#
# Every morning, a seafood shop in Amsterdam purchases fresh fish.
#
# Based on historical data, the shop expects approximately 200 customers per day. To keep the analysis manageable, we will assume that exactly 200 customers arrive during each simulated day. Customers arrive one by one, and each customer purchases a random number of fish (between 1 and 10).
#
# Because the fish must be sold fresh, any fish that remains unsold at the end of the day can no longer be offered for sale. These unsold fish are discarded, and the shop pays a waste processing company €0.50 for each fish disposed of.
#
# Each morning, the manager must decide how many fish to purchase:
#
# - If too few fish are ordered, some customers cannot be served and potential sales are lost.
# - If too many fish are ordered, unsold fish must be discarded and disposal costs are incurred.
#
# The shop wants to use Python-based simulation to evaluate different inventory levels and estimate which starting stock yields the highest average daily profit.

# %% [markdown]
# a) Import the `random` module
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# b) Use the `random` module to print a random integer between 1 and 10 (inclusive).
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# c) Write a function `daily_demand()` that:
#
# - Simulates exactly 200 customers.
# - For each customer, randomly determines how many fish are purchased (between 1 and 10).
# - Returns the total number of fish demanded by all customers combined.
#
# (3 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# d) Calculate the daily demand by calling the function `daily_demand()`. Store the returned value in a variable called `demand` and print the value.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# e) Create a variable `inventory` and assign it the value 1000.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# f) Compute the number of fish sold in a day. Recall that the shop cannot sell more fish than it acquired for the day. In other words, the number of fish sold is the minimum of inventory and demand.
#
# The approach should work for any combination of inventory and demand values. Print the number of fish sold.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# g) Compute the number of unsold fish.
#
# Unsold fish are all fish that remain after satisfying demand.
#
# The approach should work for any combination of inventory and demand values. Print the number of unsold fish.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# h) Compute the daily profit.
#
# The company uses the following pricing and cost structure:
#
# - Each fish is sold for €9
# - Each fish is purchased for €3
# - Any unsold fish must be discarded, and disposal costs are €0.50 per fish
#
#
# Profit is calculated as:
#
# `profit` = `revenue` − `purchase_costs` − `disposal_costs`
#
# where:
# - `revenue` = (number of fish sold) × 9
# - `purchase_costs` = inventory × 3
# - `disposal_costs` = (number of unsold fish) × 0.50
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# i) The next step is to create a function that can be used to examine the profit for a given inventory count.
#
# Write a function `daily_profit(inventory)`.
#
# The parameter `inventory` represents the number of fish purchased in the morning.
#
# Your function must perform the following steps in order.
#
# 1) Compute the total demand:
#     - Call the function `daily_demand()` to determine the daily demand.
# 2) Compute the number of fish sold
#     - The number of fish sold is limited by both demand and inventory.
# 3) Compute the number of unsold fish.
#     - Any fish that were purchased but not sold must be discarded.
# 4) Compute revenue
#     - Each fish sold generates €9 of revenue.
# 5) Compute purchase cost
#     - Each fish purchased costs €3, regardless of whether it is sold.
# 6) Compute disposal cost
#     - Each unsold fish costs €0.50 to dispose of.
# 7) Compute profit (sales - purchases - disposal costs)
#
# 8) Return the computed profit
#
# (3 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# j) Call the function `daily_profit()` with an inventory level of 1050. Print the profit.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# k) Write a function `simulate(inventory, nsims)` that:
#
# - Repeats `daily_profit(inventory)` exactly `nsims` times.
# - Adds all profits together.
# - Returns the average profit.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# l) Examine the expected profit for an inventory level of 1000 using `nsims = 100`.
#
# Use your function `simulate(inventory, nsims)`.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# m) Use your simulation to determine the optimal inventory level that maximizes expected profit.
#
# To do this:
#
# 1) Test different inventory levels between 900 and 1300 (inclusive).
#    You may choose a step size of 50 (i.e. 900, 950, 1000, …, 1300).
#
# 2) For each inventory level:
#    - Call `simulate(inventory, nsims)`
#    - Store or print the average profit
#
# 3) Identify the inventory level that gives the highest average profit.
#
# 4) Print:
#    - the optimal inventory level
#    - the corresponding average profit
#
#
# (3 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# # **Predicting Machine Failure**
#
# (27 points in total)

# %% [markdown]
# Predicting machine failure is essential for smooth operations, helping to minimize unexpected downtime, reduce repair costs, and extend equipment life. By proactively addressing issues, organizations can boost productivity, ensure worker safety, enhance customer satisfaction, and even reduce their environmental footprint.
#
# Machine learning models take this approach to the next level by analyzing data patterns to predict failures before they occur. These models identify early signs of wear and tear, allowing for optimized maintenance schedules that keep machinery running efficiently. With data-driven insights, organizations save on maintenance costs, maximize equipment lifespan, and maintain reliable, sustainable operations.
#
# You are provided with a dataset that provides sensor data gathered from different machines, designed to help predict failures before they happen. It includes multiple sensor measurements along with records of when each machine experienced a failure.
#
# The dataset contains the following columns:<br>
# <br>
# `footfall`: The number of people or objects passing by the machine. (CONTINUOUS)<br>
# `tempmode`: The temperature mode or setting of the machine (CATEGORICAL).<br>
# `aq`: Air quality index near the machine. (CONTINUOUS)<br>
# `uss`: Ultrasonic sensor data, indicating proximity measurements. (CONTINUOUS)<br>
# `cs`: Current sensor readings, indicating the electrical current usage of the machine. (CONTINUOUS)<br>
# `voc`: Volatile organic compounds level detected near the machine. (CONTINUOUS)<br>
# `rp`: Rotational position or RPM (revolutions per minute) of the machine parts. (CONTINUOUS)<br>
# `ip`: Input pressure to the machine. (CONTINUOUS)<br>
# `temperature`: The operating temperature of the machine. (CONTINUOUS)<br>
# `status`: Indicator of machine failure ('operational' or 'failure'). (CATEGORICAL)<br>

# %% [markdown]
# a) Import the required libraries:
# - numpy as np
# - pandas as pd
# - matplotlib.pyplot as plt
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# b) Load the dataset as a pandas DataFrame.
#
# (0 points)

# %%
import importlib.util

if importlib.util.find_spec("datadepot") is None:
    # !pip install datadepot

import datadepot
df = datadepot.load('machine_failure')

# %% [markdown]
# c) Display the top rows of the DataFrame (df)
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# d) Show the number of occurences (count) for each of the different temperature modes.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# e) Create dummy variables based on the `tempmode` column. Drop the first dummy column to prevent any multicollinearity issues.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# f) Create a function named `fail`. The function should accept a single parameter (with a value of either 'failure' or 'operational'). The function should return 1 if the value was 'failure', and 0 otherwise.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# g) Create a new column in your DataFrame with the name 'failure' by applying the previously defined function to the column 'status'.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# h) Drop the column 'status' from the DataFrame.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# i. Split your DataFrame into two parts:
#
# - `X` which contains all the features (explanatory variables)<br>
# - `y` which is your outcome variable (failure).
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# j) Split your `X` and `y` datasets into training and test datasets:
#
#   Use 80% of your sample for training and 20% of your sample for testing.
#
#   Use the `train_test_split` function from `sklearn.model_selection` to do this.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# k) Provide descriptive statistics for the variables in the `X_train` DataFrame.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# l) Normalize the columns in your X vectors (`X_train` and `X_test`). Use the `MinMaxScaler` from `sklearn.preprocessing`.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# m) Import the k-nearest neighbors classifier from Scikit-learn (`sklearn.neighbors`)
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# n) Create (load) an instance of the classifier named 'knn'. Set the number of neighbors to 5.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# o) Fit the model to the data:
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# p) Examine the accuracy of the model on the testing data.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# q) Examine the True (right) and False (wrong) predictions using a Confusion Matrix.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# r) Compute the precision score and recall score for the test data. Utilize print statements with f-strings to neatly display the scores.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# s) Import the decision tree classifier from sklearn and estimate its accuracy on the test data. Set the maximum number of layers equal to 4.
#
# (2 points)

# %%
# YOUR CODE HERE

# %% [markdown]
# t) Examine the True (right) and False (wrong) predictions using a Confusion Matrix:
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# u) Compute the precision score and recall score for the test data. Utilize print statements with f-strings to neatly display the scores.
#
# (1 point)

# %%
# YOUR CODE HERE

# %% [markdown]
# v) Discuss which model you prefer. In your answer incorporate general advantages and disadvantages of the models, and the importance of the precision and recall measures in the context of predicting machine failure.
#
# (3 points)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# -------
# End of Exam
